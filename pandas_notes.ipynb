# %% [markdown]
# <a href="https://colab.research.google.com/github/Shafeenanasar/Python-Pandas/blob/main/pandas_notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
a=np.linspace(1,100,10)

# %%
a
# Out:
# array([  1.,  12.,  23.,  34.,  45.,  56.,  67.,  78.,  89., 100.])

# %%
b=pd.Series(a)

# %%
b
# Out:
# 0      1.0
# 1     12.0
# 2     23.0
# 3     34.0
# 4     45.0
# 5     56.0
# 6     67.0
# 7     78.0
# 8     89.0
# 9    100.0
# dtype: float64

# %%
c={'a':0,'b':1,'c':2}

# %%
d=pd.Series(c)

# %%
d
# Out:
# a    0
# b    1
# c    2
# dtype: int64

# %% [markdown]
# # [DataFrame] df

# %%
data={
    "A":[5,6,7],
    "B":[1,7,8],
    "C":[9,5,8]
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    A  B  C
# 0  5  1  9
# 1  6  7  5
# 2  7  8  8

# %%
data1={
    "A":[5],
    "B":[4]
    }

# %%
df1=pd.DataFrame(data1)

# %%
df1
# Out:
#    A  B
# 0  5  4

# %%
arr=np.random.randint(0,100)

# %%
arr
# Out:
# 64

# %%
arr=np.random.randint(0,100,20)
arr
# Out:
# array([17, 12, 58, 27, 96, 82,  4, 84, 67, 60, 98, 95, 93, 25, 11, 17, 63,
#         7, 81, 29])

# %%
arr=np.random.randint(0,100,(2,3))
arr
# Out:
# array([[20, 42, 15],
#        [66, 52,  0]])

# %%
rowname=['mon','tue']
cols=['jan','feb','mar']

# %%
df=pd.DataFrame(arr,index=rowname,columns=cols)
df
# Out:
#      jan  feb  mar
# mon   20   42   15
# tue   66   52    0

# %%
path='/content/weather_data.csv'

# %%
df=pd.read_csv(path)

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.head(3)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
df.tail(2)
# Out:
#         day  temperature  windspeed  event
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.shape
# Out:
# (6, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          6 non-null      object
#  1   temperature  6 non-null      int64
#  2   windspeed    6 non-null      int64
#  3   event        6 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 320.0+ bytes

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df.rename(columns={'windspeed':'wind_speed'})
# Out:
#         day  temperature  wind_speed  event
# 0  1/1/2017           32           6   Rain
# 1  1/2/2017           35           7  Sunny
# 2  1/3/2017           28           2   Snow
# 3  1/4/2017           24           7   Snow
# 4  1/5/2017           32           4   Rain
# 5  1/6/2017           31           2  Sunny

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.rename(columns={'windspeed':'wind_speed'},inplace=True)
df
# Out:
#         day  temperature  wind_speed  event
# 0  1/1/2017           32           6   Rain
# 1  1/2/2017           35           7  Sunny
# 2  1/3/2017           28           2   Snow
# 3  1/4/2017           24           7   Snow
# 4  1/5/2017           32           4   Rain
# 5  1/6/2017           31           2  Sunny

# %%
df.rename(lambda x:x.replace('_','-'),axis='columns')
# Out:
#         day  temperature  wind-speed  event
# 0  1/1/2017           32           6   Rain
# 1  1/2/2017           35           7  Sunny
# 2  1/3/2017           28           2   Snow
# 3  1/4/2017           24           7   Snow
# 4  1/5/2017           32           4   Rain
# 5  1/6/2017           31           2  Sunny

# %%
df['day'][df['temperature']==df.temperature.max()]
# Out:
# 1    1/2/2017
# Name: day, dtype: object

# %%
df['day'][df['temperature']>df.temperature.mean()]
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
df[['day','temperature']][df['temperature']>df.temperature.mean()]
# Out:
#         day  temperature
# 0  1/1/2017           32
# 1  1/2/2017           35
# 4  1/5/2017           32
# 5  1/6/2017           31

# %%
df['temperature']>30
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4     True
# 5     True
# Name: temperature, dtype: bool

# %%
df[df['temperature']>30]
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df['day'][df['temperature']>30]
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
df[['day','event']][df['temperature']>30]
# Out:
#         day  event
# 0  1/1/2017   Rain
# 1  1/2/2017  Sunny
# 4  1/5/2017   Rain
# 5  1/6/2017  Sunny

# %%
df[(df['temperature']<30) | (df['windspeed']>5)]
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow

# %%
df[(df['temperature']>30) & (df['windspeed']<5) | (df['temperature']<30) & (df['windspeed']>5)]
# Out:
#         day  temperature  windspeed  event
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df[['temperature','windspeed']][(df['temperature']>30) & (df['windspeed']<5) | (df['temperature']<30) & (df['windspeed']>5)]
# Out:
#    temperature  windspeed
# 3           24          7
# 4           32          4
# 5           31          2

# %% [markdown]
# #using loc

# %% [markdown]
# loc means position
# 0th position - event prints

# %%
df.loc[0,'event']
# Out:
# 'Rain'

# %%
df.loc[0:3,['event','windspeed']]
# Out:
#    event  windspeed
# 0   Rain          6
# 1  Sunny          7
# 2   Snow          2
# 3   Snow          7

# %%
df.loc[[1,3,4],['event','windspeed']]
# Out:
#    event  windspeed
# 1  Sunny          7
# 3   Snow          7
# 4   Rain          4

# %%
df.set_index('day',inplace=True)

# %%
df
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %%
df.reset_index
# Out:
# <bound method DataFrame.reset_index of           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny>

# %% [markdown]
# Extract 2 fields using the specific index

# %%
df.loc['1/1/2017':'1/4/2017',['event','temperature']]
# Out:
#           event  temperature
# day
# 1/1/2017   Rain           32
# 1/2/2017  Sunny           35
# 1/3/2017   Snow           28
# 1/4/2017   Snow           24

# %% [markdown]
# OR

# %%
df.loc[['1/1/2017','1/2/2017'],['event','temperature','windspeed']]
# Out:
#           event  temperature  windspeed
# day
# 1/1/2017   Rain           32          6
# 1/2/2017  Sunny           35          7

# %%
data = pd.DataFrame({'Brand': ['Maruti', 'Hyundai', 'Tata',
                               'Mahindra', 'Maruti', 'Hyundai',
                               'Renault', 'Tata', 'Maruti'],
                     'Year': [2012, 2014, 2011, 2015, 2012,
                              2016, 2014, 2018, 2019],
                     'Kms Driven': [50000, 30000, 60000,
                                    25000, 10000, 46000,
                                    31000, 15000, 12000],
                     'City': ['Gurgaon', 'Delhi', 'Mumbai',
                              'Delhi', 'Mumbai', 'Delhi',
                              'Mumbai', 'Chennai',  'Ghaziabad'],
                     'Mileage':  [28, 27, 25, 26, 28,
                                  29, 24, 21, 24]})

# %%
data
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 0    Maruti  2012       50000    Gurgaon       28
# 1   Hyundai  2014       30000      Delhi       27
# 2      Tata  2011       60000     Mumbai       25
# 3  Mahindra  2015       25000      Delhi       26
# 4    Maruti  2012       10000     Mumbai       28
# 5   Hyundai  2016       46000      Delhi       29
# 6   Renault  2014       31000     Mumbai       24
# 7      Tata  2018       15000    Chennai       21
# 8    Maruti  2019       12000  Ghaziabad       24

# %%
#brand maruti and mileage greater than 25
data.loc[(data['Brand']=='Maruti') & (data['Mileage']>25)]
# Out:
#     Brand  Year  Kms Driven     City  Mileage
# 0  Maruti  2012       50000  Gurgaon       28
# 4  Maruti  2012       10000   Mumbai       28

# %%
data.loc[(data['Brand']=='Maruti') & (data['Mileage']>25),'City']
# Out:
# 0    Gurgaon
# 4     Mumbai
# Name: City, dtype: object

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.iloc[0:3]
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
df.iloc[0:3,2]
# Out:
# 0    6
# 1    7
# 2    2
# Name: windspeed, dtype: int64

# %%
df.iloc[0,2]
# Out:
# 6

# %%
df.iloc[[1,2,3],[0,1]]
# Out:
#         day  temperature
# 1  1/2/2017           35
# 2  1/3/2017           28
# 3  1/4/2017           24

# %%
x=df.groupby('event')['temperature'].mean()
x
# Out:
# event
# Rain     32.0
# Snow     26.0
# Sunny    33.0
# Name: temperature, dtype: float64

# %%
x=df.groupby('event')['temperature'].mean().reset_index()
x
# Out:
#    event  temperature
# 0   Rain         32.0
# 1   Snow         26.0
# 2  Sunny         33.0

# %%
x=df.groupby('event')['temperature'].mean().sort_values().reset_index()
x
# Out:
#    event  temperature
# 0   Snow         26.0
# 1   Rain         32.0
# 2  Sunny         33.0

# %%
x=df.groupby('event')['temperature'].agg(['sum','mean']).reset_index()
x
# Out:
#    event  sum  mean
# 0   Rain   64  32.0
# 1   Snow   52  26.0
# 2  Sunny   66  33.0

# %% [markdown]
# # returns all the values aggregation method of Numerical datas

# %%
df.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %% [markdown]
# # Sorting dataframe

# %% [markdown]
# **Ascending----default**

# %%
df.sort_values(by='temperature')
# Out:
#         day  temperature  windspeed  event
# 3  1/4/2017           24          7   Snow
# 2  1/3/2017           28          2   Snow
# 5  1/6/2017           31          2  Sunny
# 0  1/1/2017           32          6   Rain
# 4  1/5/2017           32          4   Rain
# 1  1/2/2017           35          7  Sunny

# %% [markdown]
# **Descending**

# %%
df.sort_values(by='temperature',ascending=False)
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 0  1/1/2017           32          6   Rain
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow

# %%
def sum(num1,num2):
  add=a+b
  return add

a=int(input('Enter number1'))
b=int(input('Enter number2'))
add=sum(a,b)
print(add)
# Out:
# Enter number12
# Enter number23
# 5

# %%
def fun(fare,para):
  if(para<fare):
    print('low fare')
  elif(para>20)&(para<100):
    print('medium fare')
  else:
    print('high fare')

fare=int(input('Enter the fare'))
para=int(input('Enter the parameter'))
fun(fare,para)
print('end')
# Out:
# Enter the fare25
# Enter the parameter6
# low fare
# end
